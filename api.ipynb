# %%
import requests
import pandas as pd
import sqlite3

base_url = "https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document"
params = {
    "$filter": "Verwijderd eq false",  # Only non-deleted documents
    "$top": "100"                      # Get the top 100 documents (adjust as needed)
}


response = requests.get(base_url, params=params)
if response.status_code == 200:
    data = response.json()
    documents = data.get("value", [])
    df = pd.DataFrame(documents)
    print(df.head())

    df.to_csv("tweede_kamer_documents.csv", index=False)
    print("Data saved to tweede_kamer_documents.csv")
    conn = sqlite3.connect("tweede_kamer.db")
    df.to_sql("documents", conn, if_exists="replace", index=False)
    conn.close()
    print("Data stored in tweede_kamer.db (table 'documents')")
else:
    print("Error: Failed to fetch data. Status code:", response.status_code)
# Out:
#                                      Id                             Soort  \
# 0  88fa70bf-c3e0-41d0-8d42-000044df3ecd        Verslag van een rapporteur
# 1  ec9315bf-e1d1-422e-a8fb-0000932ed927     Antwoord schriftelijke vragen
# 2  b3eb0622-4769-4bd9-bb96-0000b9b06215     Mededeling (uitstel antwoord)
# 3  aeca2740-1abe-4acd-acb0-0000bb0e5797     Antwoord schriftelijke vragen
# 4  5c345160-d91d-40a0-ad7d-0000cf59de18  Verslag van een algemeen overleg
#
#   DocumentNummer                            Titel  \
# 0     2018D03877                             None
# 1     2019D16854                             None
# 2     2019D31935                             None
# 3     2012D06529                             None
# 4     2014D27578  Duurzame ontwikkeling en beleid
#
#                                            Onderwerp  \
# 0  Vierde voortgangsverslag Rapporteurschap Europ...
# 1  Antwoord op vragen van het lid Van Nispen over...
# ...
